# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
## starting with the inputs

# %%
## enter the values in order(all in SI units): length, YoungModulus, A0, nodes, elements, availNodes, fixedNode, force

# %%
inputs_list = dict() 
for i in range(8):
    data = input('Enter key & value separated by ":", ') 
    temp = data.split(':') 
    inputs_list[temp[0]] = temp[1] 
print()
# Displaying the dictionary 
for key, value in inputs_list.items(): 
    inputs_list[key] = float(value)
    print(f'Key: {key}, Value: {value}') 
print(inputs_list)
# Out:
# Enter key & value separated by ":", length:0.5
# Enter key & value separated by ":", YoungModulus:70e9
# Enter key & value separated by ":", A0:0.00125
# Enter key & value separated by ":", elements:2
# Enter key & value separated by ":", nodes:3
# Enter key & value separated by ":", availNodes:2
# Enter key & value separated by ":", fixedNode:1
# Enter key & value separated by ":", force:-5000
#
# Key: length, Value: 0.5
# Key: YoungModulus, Value: 70e9
# Key: A0, Value: 0.00125
# Key: elements, Value: 2
# Key: nodes, Value: 3
# Key: availNodes, Value: 2
# Key: fixedNode, Value: 1
# Key: force, Value: -5000
# {'length': 0.5, 'YoungModulus': 70000000000.0, 'A0': 0.00125, 'elements': 2.0, 'nodes': 3.0, 'availNodes': 2.0, 'fixedNode': 1.0, 'force': -5000.0}

# %%
type(inputs_list['length'])
# Out:
# float

# %%
t=np.array([[1,-1],[-1,1]])

# %%
t
# Out:
# array([[ 1, -1],
#        [-1,  1]])

# %%
import numpy
elementalLength = inputs_list['length'] / (int(inputs_list['elements']))
nodesPosi = [i * elementalLength  for i in range(int(inputs_list['elements'])+1)]
nodesPosi= numpy.transpose(nodesPosi).reshape(-1,1)

# %%
nodesPosi
# Out:
# array([[0.  ],
#        [0.25],
#        [0.5 ]])

# %%
inputs_list['nodes'] = int(inputs_list['nodes'])

# %%
## global stiffness matrix, force arrangement
kg=np.zeros((inputs_list['nodes'], inputs_list['nodes']))
u = np.zeros((inputs_list['nodes'],1))
F = np.zeros((inputs_list['nodes'],1))
F[0]= inputs_list['force']
FE= F[:int(inputs_list['elements']),:int(inputs_list['elements'])]

# %%
## description of the problem

# %%
area = inputs_list['A0']
K = ( inputs_list['A0']* inputs_list['YoungModulus'] /elementalLength ) * t
for i in range(int(inputs_list['elements'])):
    print(i)
    x = i
    idx = [i, i + 1]
    kg[np.ix_(idx, idx)] += K
print(K)
print('Global Stiffness Matrix is:')
print(kg)
# Out:
# 0
# 1
# [[ 3.5e+08 -3.5e+08]
#  [-3.5e+08  3.5e+08]]
# Global Stiffness Matrix is:
# [[ 1.75e+09 -1.75e+09  0.00e+00]
#  [-1.75e+09  3.50e+09 -1.75e+09]
#  [ 0.00e+00 -1.75e+09  1.75e+09]]

# %%
def problem_case():
    # asking about the test case
    info = input("Is the problem based on uniform cross secional area (Y/N): ")
    if(info == 'Y'):
        area = inputs_list['A0']
        K = ( inputs_list['A0']* inputs_list['YoungModulus'] /elementalLength ) * t
        for i in range(int(inputs_list['elements'])):
            x = i
            idx = [i, i + 1]
            kg[np.ix_(idx, idx)] += K
        print('Global Stiffness Matrix is:')
        print(kg)
        KGE= kg[:int(inputs_list['elements']),:int(inputs_list['elements'])]
        uE = np.linalg.solve(KGE, FE)
        u[:int(inputs_list['elements'])]=uE
       # U1=u.reshape(-1,1)
        print('Numerical deflection matrix is:')
        print(u)
        ReactionForce = np.dot(kg[int(inputs_list['elements'])], u)
        print(f'Reaction force at x=L is: {ReactionForce}')
       
    ## Analytical solution
        u1a_x = []
        for i in nodesPosi:
            val = 5000*(i-inputs_list['length'])/(inputs_list['YoungModulus']*inputs_list['A0'])
            u1a_x.append(val)
        u1a_x_array = np.array(u1a_x).reshape(-1, 1)
        print('Analytical deflection matrix is:')
        print(u1a_x_array)
           # u1a_x = np.array(u1a_x).reshape(-1,1)
            
            
        
    ## plotting analytical vs numerical
        x = nodesPosi
        y1 = u1a_x_array
        y2 = u
        z = u-u1a_x_array
        figure,axes = plt.subplots(2,1)
       # axes[0] = fig.add_axes([0,0,1,1])
        axes[0].plot(x,y1,color="green",lw=2,ls="--",marker='o',markersize=3,label='analytical')
        axes[0].plot(x,y2,color="red",lw=2,ls="-",marker='+',markersize=7,label='numerical')
        plt.xlabel("nodal locations ")
        plt.ylabel("Magnitude")
     #   plt.title("Analytical vs Numerical",pad=10)
        axes[0].legend()
       # axes[1] = fig.add_axes([0,0,1,1])
        axes[1].plot(x,z,color="green",lw=2,ls="--",marker='o',markersize=5,label='norm(uN-uA)')
        plt.xlabel("nodal locations ")
        plt.ylabel("Magnitude")
     #   plt.title("uN-uA")
        axes[1].legend()


    elif(info == 'N'):
        for i in range(int(inputs_list['elements'])):
            x = i
            A_x =  inputs_list['A0']* (1 + ((nodesPosi[x] + nodesPosi[x+1]) / (2 * inputs_list['length'])))
            print(f"A_x({x}) = {A_x}")
    
            K = (A_x * inputs_list['YoungModulus'] /elementalLength ) * t
            print(f"K({x}) =\n{K}")
            idx = [i, i + 1]
            kg[np.ix_(idx, idx)] += K
            
        print('Global Stiffness Matrix is:')
        print(kg)
        KGE= kg[:int(inputs_list['elements']),:int(inputs_list['elements'])]
        uE = np.linalg.solve(KGE, FE)
        u[:int(inputs_list['elements'])]=uE
        print('Numerical deflection matrix is:')
        print(u)
        ReactionForce = np.dot(kg[int(inputs_list['elements'])], u)
        print(f'Reaction force at x=L is: {ReactionForce}')      
       
    ## Analytical solution
        u2a_x = []
        for i in nodesPosi:
            valu = (5000*inputs_list['length']*np.log((inputs_list['length']+i)/(2*inputs_list['length'])))/(inputs_list['YoungModulus']*inputs_list['A0'])
            u2a_x.append(valu)
        u2a_x_array = np.array(u2a_x).reshape(-1, 1)
        print('Analytical deflection matrix is:')
        print(u2a_x_array)
        
       
    ## plotting analytical vs numerical
        x = nodesPosi
        y1 = u2a_x_array
        y2 = u
        z = u-u2a_x_array
        figure,axes = plt.subplots(2,1)
        #axes[0] = fig.add_axes([0,0,1,1])
        axes[0].plot(x,y1,color="green",lw=2,ls="--",marker='o',markersize=5,label='analytical')
        axes[0].plot(x,y2,color="red",lw=2,ls="-",marker='+',markersize=7,label='numerical')
        plt.xlabel("nodal locations ")
        plt.ylabel("Magnitude")
      #  plt.title("Analytical vs Numerical",pad = 10)
        axes[0].legend()
       # axes[1] = fig.add_axes([0,0,1,1])
        axes[1].plot(x,z,color="green",lw=2,ls="--",marker='o',markersize=5,label='norm(uN-uA)')
        plt.xlabel("nodal locations ")
        plt.ylabel("Magnitude")
      #  plt.title("uN-uA")
        axes[1].legend()

# %%
problem_case()
# Out:
# Is the problem based on uniform cross secional area (Y/N): N
# A_x(0) = [0.00126953]
# K(0) =
# [[ 5.6875e+09 -5.6875e+09]
#  [-5.6875e+09  5.6875e+09]]
# A_x(1) = [0.00130859]
# K(1) =
# [[ 5.8625e+09 -5.8625e+09]
#  [-5.8625e+09  5.8625e+09]]
# A_x(2) = [0.00134766]
# K(2) =
# [[ 6.0375e+09 -6.0375e+09]
#  [-6.0375e+09  6.0375e+09]]
# A_x(3) = [0.00138672]
# K(3) =
# [[ 6.2125e+09 -6.2125e+09]
#  [-6.2125e+09  6.2125e+09]]
# A_x(4) = [0.00142578]
# K(4) =
# [[ 6.3875e+09 -6.3875e+09]
#  [-6.3875e+09  6.3875e+09]]
# A_x(5) = [0.00146484]
# K(5) =
# [[ 6.5625e+09 -6.5625e+09]
#  [-6.5625e+09  6.5625e+09]]
# A_x(6) = [0.00150391]
# K(6) =
# [[ 6.7375e+09 -6.7375e+09]
#  [-6.7375e+09  6.7375e+09]]
# A_x(7) = [0.00154297]
# K(7) =
# [[ 6.9125e+09 -6.9125e+09]
#  [-6.9125e+09  6.9125e+09]]
# A_x(8) = [0.00158203]
# K(8) =
# [[ 7.0875e+09 -7.0875e+09]
#  [-7.0875e+09  7.0875e+09]]
# A_x(9) = [0.00162109]
# K(9) =
# [[ 7.2625e+09 -7.2625e+09]
#  [-7.2625e+09  7.2625e+09]]
# A_x(10) = [0.00166016]
# K(10) =
# [[ 7.4375e+09 -7.4375e+09]
#  [-7.4375e+09  7.4375e+09]]
# A_x(11) = [0.00169922]
# K(11) =
# [[ 7.6125e+09 -7.6125e+09]
#  [-7.6125e+09  7.6125e+09]]
# A_x(12) = [0.00173828]
# K(12) =
# [[ 7.7875e+09 -7.7875e+09]
#  [-7.7875e+09  7.7875e+09]]
# A_x(13) = [0.00177734]
# K(13) =
# [[ 7.9625e+09 -7.9625e+09]
#  [-7.9625e+09  7.9625e+09]]
# A_x(14) = [0.00181641]
# K(14) =
# [[ 8.1375e+09 -8.1375e+09]
#  [-8.1375e+09  8.1375e+09]]
# A_x(15) = [0.00185547]
# K(15) =
# [[ 8.3125e+09 -8.3125e+09]
#  [-8.3125e+09  8.3125e+09]]
# A_x(16) = [0.00189453]
# K(16) =
# [[ 8.4875e+09 -8.4875e+09]
#  [-8.4875e+09  8.4875e+09]]
# A_x(17) = [0.00193359]
# K(17) =
# [[ 8.6625e+09 -8.6625e+09]
#  [-8.6625e+09  8.6625e+09]]
# A_x(18) = [0.00197266]
# K(18) =
# [[ 8.8375e+09 -8.8375e+09]
#  [-8.8375e+09  8.8375e+09]]
# A_x(19) = [0.00201172]
# K(19) =
# [[ 9.0125e+09 -9.0125e+09]
#  [-9.0125e+09  9.0125e+09]]
# A_x(20) = [0.00205078]
# K(20) =
# [[ 9.1875e+09 -9.1875e+09]
#  [-9.1875e+09  9.1875e+09]]
# A_x(21) = [0.00208984]
# K(21) =
# [[ 9.3625e+09 -9.3625e+09]
#  [-9.3625e+09  9.3625e+09]]
# A_x(22) = [0.00212891]
# K(22) =
# [[ 9.5375e+09 -9.5375e+09]
#  [-9.5375e+09  9.5375e+09]]
# A_x(23) = [0.00216797]
# K(23) =
# [[ 9.7125e+09 -9.7125e+09]
#  [-9.7125e+09  9.7125e+09]]
# A_x(24) = [0.00220703]
# K(24) =
# [[ 9.8875e+09 -9.8875e+09]
#  [-9.8875e+09  9.8875e+09]]
# A_x(25) = [0.00224609]
# K(25) =
# [[ 1.00625e+10 -1.00625e+10]
#  [-1.00625e+10  1.00625e+10]]
# A_x(26) = [0.00228516]
# K(26) =
# [[ 1.02375e+10 -1.02375e+10]
#  [-1.02375e+10  1.02375e+10]]
# A_x(27) = [0.00232422]
# K(27) =
# [[ 1.04125e+10 -1.04125e+10]
#  [-1.04125e+10  1.04125e+10]]
# A_x(28) = [0.00236328]
# K(28) =
# [[ 1.05875e+10 -1.05875e+10]
#  [-1.05875e+10  1.05875e+10]]
# A_x(29) = [0.00240234]
# K(29) =
# [[ 1.07625e+10 -1.07625e+10]
#  [-1.07625e+10  1.07625e+10]]
# A_x(30) = [0.00244141]
# K(30) =
# [[ 1.09375e+10 -1.09375e+10]
#  [-1.09375e+10  1.09375e+10]]
# A_x(31) = [0.00248047]
# K(31) =
# [[ 1.11125e+10 -1.11125e+10]
#  [-1.11125e+10  1.11125e+10]]
# Global Stiffness Matrix is:
# [[ 5.68750e+09 -5.68750e+09  0.00000e+00 ...  0.00000e+00  0.00000e+00
#    0.00000e+00]
#  [-5.68750e+09  1.15500e+10 -5.86250e+09 ...  0.00000e+00  0.00000e+00
#    0.00000e+00]
#  [ 0.00000e+00 -5.86250e+09  1.19000e+10 ...  0.00000e+00  0.00000e+00
#    0.00000e+00]
#  ...
#  [ 0.00000e+00  0.00000e+00  0.00000e+00 ...  2.17000e+10 -1.09375e+10
#    0.00000e+00]
#  [ 0.00000e+00  0.00000e+00  0.00000e+00 ... -1.09375e+10  2.20500e+10
#   -1.11125e+10]
#  [ 0.00000e+00  0.00000e+00  0.00000e+00 ...  0.00000e+00 -1.11125e+10
#    1.11125e+10]]
# Numerical deflection matrix is:
# [[-1.98033334e-05]
#  [-1.89242125e-05]
#  [-1.80713341e-05]
#  [-1.72431767e-05]
#  [-1.64383477e-05]
#  [-1.56555689e-05]
#  [-1.48936641e-05]
#  [-1.41515491e-05]
#  [-1.34282218e-05]
#  [-1.27227544e-05]
#  [-1.20342863e-05]
#  [-1.13620173e-05]
#  [-1.07052029e-05]
#  [-1.00631483e-05]
#  [-9.43520484e-06]
#  [-8.82076551e-06]
#  [-8.21926176e-06]
#  [-7.63016013e-06]
#  [-7.05295956e-06]
#  [-6.48718869e-06]
#  [-5.93240367e-06]
#  [-5.38818599e-06]
#  [-4.85414059e-06]
#  [-4.32989420e-06]
#  [-3.81509368e-06]
#  [-3.30940468e-06]
#  [-2.81251027e-06]
#  [-2.32410978e-06]
#  [-1.84391771e-06]
#  [-1.37166269e-06]
#  [-9.07086614e-07]
#  [-4.49943757e-07]
#  [ 0.00000000e+00]]
# Reaction force at x=L is: [5000.]
# Analytical deflection matrix is:
# [[-1.98042052e-05]
#  [-1.89250149e-05]
#  [-1.80720731e-05]
#  [-1.72438578e-05]
#  [-1.64389756e-05]
#  [-1.56561477e-05]
#  [-1.48941978e-05]
#  [-1.41520411e-05]
#  [-1.34286751e-05]
#  [-1.27231719e-05]
#  [-1.20346704e-05]
#  [-1.13623705e-05]
#  [-1.07055271e-05]
#  [-1.00634455e-05]
#  [-9.43547677e-06]
#  [-8.82101376e-06]
#  [-8.21948778e-06]
#  [-7.63036529e-06]
#  [-7.05314508e-06]
#  [-6.48735573e-06]
#  [-5.93255328e-06]
#  [-5.38831914e-06]
#  [-4.85425819e-06]
#  [-4.32999709e-06]
#  [-3.81518265e-06]
#  [-3.30948044e-06]
#  [-2.81257351e-06]
#  [-2.32416113e-06]
#  [-1.84395775e-06]
#  [-1.37169198e-06]
#  [-9.07105666e-07]
#  [-4.49953056e-07]
#  [ 0.00000000e+00]]
